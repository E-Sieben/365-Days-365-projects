# %%
# Getting Data
from sys import path
path.append('../..')
from getTrainingData import getTrainingData

# Get data using the improved function
data = getTrainingData(test_size=0.2, random_state=42, scale_features=True)
data
# Out:
# {'X_train':      category_accessories  category_baby  category_dresses  category_jackets  \
#  137             -0.163398      -0.170872         -0.204626         -0.378475
#  36              -0.163398      -0.170872         -0.204626         -0.378475
#  89              -0.163398      -0.170872         -0.204626         -0.378475
#  373             -0.163398      -0.170872         -0.204626          2.642183
#  467             -0.163398      -0.170872         -0.204626         -0.378475
#  ..                    ...            ...               ...               ...
#  76              -0.163398      -0.170872         -0.204626         -0.378475
#  111             -0.163398      -0.170872         -0.204626         -0.378475
#  353             -0.163398      -0.170872         -0.204626         -0.378475
#  435             -0.163398      -0.170872         -0.204626         -0.378475
#  107             -0.163398      -0.170872         -0.204626         -0.378475
#
#       category_jeans  category_other  category_pants  category_sets  \
#  137       -0.239792       -0.245256       -0.366126      -0.129719
#  36        -0.239792       -0.245256       -0.366126      -0.129719
#  89        -0.239792        4.077377       -0.366126      -0.129719
#  373       -0.239792       -0.245256       -0.366126      -0.129719
#  467       -0.239792       -0.245256       -0.366126      -0.129719
#  ..              ...             ...             ...            ...
#  76         4.170288       -0.245256       -0.366126      -0.129719
#  111        4.170288       -0.245256       -0.366126      -0.129719
#  353       -0.239792       -0.245256       -0.366126      -0.129719
#  435       -0.239792       -0.245256       -0.366126      -0.129719
#  107       -0.239792       -0.245256       -0.366126      -0.129719
#
#       category_shirts  category_skirts  ...   tapered    teilig       und  \
#  137         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  36          1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  89         -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  373        -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  467        -0.662401        11.832160  ... -0.118458 -0.277808 -0.219373
#  ..               ...              ...  ...       ...       ...       ...
#  76         -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  111        -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  353        -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  435         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  107         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#
#          waist  wasserabweisend       way     weste      wide  day_of_week  \
#  137 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  36  -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  89  -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  373 -0.227136        -0.146398  7.829626 -0.148822 -0.155115          0.0
#  467 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  ..        ...              ...       ...       ...       ...          ...
#  76   4.004695        -0.146398 -0.129414 -0.148822  6.285143          0.0
#  111  4.371942        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  353 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  435 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  107 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#
#       month
#  137    0.0
#  36     0.0
#  89     0.0
#  373    0.0
#  467    0.0
#  ..     ...
#  76     0.0
#  111    0.0
#  353    0.0
#  435    0.0
#  107    0.0
#
#  [338 rows x 136 columns],
#  'X_test':      category_accessories  category_baby  category_dresses  category_jackets  \
#  152             -0.163398      -0.170872         -0.204626         -0.378475
#  363             -0.163398       5.852350         -0.204626         -0.378475
#  254             -0.163398      -0.170872         -0.204626         -0.378475
#  503             -0.163398      -0.170872         -0.204626         -0.378475
#  514             -0.163398      -0.170872         -0.204626         -0.378475
#  ..                    ...            ...               ...               ...
#  62              -0.163398      -0.170872         -0.204626         -0.378475
#  507             -0.163398      -0.170872         -0.204626         -0.378475
#  29              -0.163398      -0.170872         -0.204626         -0.378475
#  22              -0.163398      -0.170872         -0.204626         -0.378475
#  71              -0.163398      -0.170872         -0.204626         -0.378475
#
#       category_jeans  category_other  category_pants  category_sets  \
#  152       -0.239792       -0.245256       -0.366126      -0.129719
#  363       -0.239792       -0.245256       -0.366126      -0.129719
#  254       -0.239792       -0.245256       -0.366126      -0.129719
#  503       -0.239792       -0.245256       -0.366126      -0.129719
#  514       -0.239792       -0.245256       -0.366126      -0.129719
#  ..              ...             ...             ...            ...
#  62        -0.239792       -0.245256       -0.366126      -0.129719
#  507       -0.239792       -0.245256       -0.366126      -0.129719
#  29        -0.239792       -0.245256       -0.366126      -0.129719
#  22        -0.239792       -0.245256       -0.366126      -0.129719
#  71         4.170288       -0.245256       -0.366126      -0.129719
#
#       category_shirts  category_skirts  ...   tapered    teilig       und  \
#  152        -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#  363        -0.662401        -0.084515  ... -0.118458  3.222477 -0.219373
#  254        -0.662401        -0.084515  ... -0.118458  3.208043  4.120507
#  503         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  514         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  ..               ...              ...  ...       ...       ...       ...
#  62          1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  507         1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  29          1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  22          1.509659        -0.084515  ... -0.118458 -0.277808 -0.219373
#  71         -0.662401        -0.084515  ... -0.118458 -0.277808 -0.219373
#
#          waist  wasserabweisend       way     weste      wide  day_of_week  \
#  152 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  363 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  254 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  503 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  514 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  ..        ...              ...       ...       ...       ...          ...
#  62  -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  507 -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  29  -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  22  -0.227136        -0.146398 -0.129414 -0.148822 -0.155115          0.0
#  71   4.142795        -0.146398 -0.129414 -0.148822  6.495313          0.0
#
#       month
#  152    0.0
#  363    0.0
#  254    0.0
#  503    0.0
#  514    0.0
#  ..     ...
#  62     0.0
#  507    0.0
#  29     0.0
#  22     0.0
#  71     0.0
#
#  [85 rows x 136 columns],
#  'y_train': 137    14.99
#  36     19.99
#  89     22.99
#  373    79.99
#  467    29.99
#         ...
#  76     39.99
#  111    39.99
#  353    14.99
#  435    39.99
#  107    12.99
#  Name: price_numeric, Length: 338, dtype: float64,
#  'y_test': 152    25.99
#  363    17.99
#  254    34.99
#  503    39.99
#  514    29.99
#         ...
#  62     19.99
#  507    29.99
#  29     29.99
#  22     25.99
#  71     39.99
#  Name: price_numeric, Length: 85, dtype: float64,
#  'feature_names': ['category_accessories',
#   'category_baby',
#   'category_dresses',
#   'category_jackets',
#   'category_jeans',
#   'category_other',
#   'category_pants',
#   'category_sets',
#   'category_shirts',
#   'category_skirts',
#   'category_sleep',
#   'category_sweaters',
#   'category_swimwear',
#   'category_underwear',
#   'category_vests',
#   'type_bag',
#   'type_blazer',
#   'type_bluse',
#   'type_cardigan',
#   'type_hemd',
#   'type_hoodie',
#   'type_jeans',
#   'type_leggings',
#   'type_other',
#   'type_poloshirt',
#   'type_pullover',
#   'type_shirt',
#   'type_shorts',
#   'type_steppjacke',
#   'type_suit',
#   'type_t-shirt',
#   'type_top',
#   'type_tshirt',
#   'type_vest',
#   '2er',
#   '3er',
#   '5er',
#   'ausschnitt',
#   'baby',
#   'badeshorts',
#   'baggy',
#   'baseballcap',
#   'baukasten',
#   'blazer',
#   'bluse',
#   'body',
#   'bouclé',
#   'business',
#   'businesshemd',
#   'button',
#   'bügelleicht',
#   'chino',
#   'crop',
#   'cutaway',
#   'der',
#   'die',
#   'dino',
#   'down',
#   'eiskönigin',
#   'feinstrick',
#   'fit',
#   'flare',
#   'flex',
#   'funktions',
#   'geblümt',
#   'gemustert',
#   'gerippt',
#   'gestreift',
#   'gürtel',
#   'hemd',
#   'high',
#   'hoodie',
#   'hose',
#   'jacke',
#   'jeans',
#   'jeanshemd',
#   'jogginghose',
#   'kapuze',
#   'kariert',
#   'kent',
#   'kleid',
#   'kurzarm',
#   'kurzarmshirt',
#   'könig',
#   'leg',
#   'leinen',
#   'leo',
#   'lilo',
#   'longblazer',
#   'lycra',
#   'löwen',
#   'man',
#   'match',
#   'maus',
#   'micky',
#   'mid',
#   'minecraft',
#   'minnie',
#   'mit',
#   'mix',
#   'motiv',
#   'multipack',
#   'nadelstreifen',
#   'outfit',
#   'oversized',
#   'print',
#   'pullover',
#   'pyjama',
#   'regular',
#   'relaxed',
#   'rock',
#   'sakko',
#   'set',
#   'shirt',
#   'slim',
#   'socken',
#   'spider',
#   'stehkragen',
#   'steppjacke',
#   'stitch',
#   'stoffhose',
#   'stretch',
#   'strickpullover',
#   'strukturiert',
#   'sweatjacke',
#   'sweatshirt',
#   'tapered',
#   'teilig',
#   'und',
#   'waist',
#   'wasserabweisend',
#   'way',
#   'weste',
#   'wide',
#   'day_of_week',
#   'month'],
#  'encoder': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'vectorizer': TfidfVectorizer(max_features=100),
#  'scaler': StandardScaler(),
#  'original_data':      product_id                                              title  price  \
#  0       2230658                    Baby-Jacke mit Kapuze - geblümt  22,99
#  1       2228972            Blümchen - 3-in-1-Baby-Jacke mit Kapuze  29,99
#  2       2229059            Baby-Jacke mit Kapuze - wasserabweisend  22,99
#  3       2233203                         Baby-Sweatjacke mit Kapuze  12,99
#  4       2230657                   Blümchen - Baby-Jacke mit Kapuze  22,99
#  ..          ...                                                ...    ...
#  513     2192572  Businesshemd - Regular Fit - Cutaway - bügelle...  39,99
#  514     2186159       Businesshemd - Slim Fit - Kent - bügelleicht  29,99
#  516     2192522    Businesshemd - Regular Fit - Kent - bügelleicht  29,99
#  517     2192773    Businesshemd - Regular Fit - Kent - bügelleicht  29,99
#  518     2205630    Businesshemd - Regular Fit - Kent - bügelleicht  29,99
#
#       category   type                                          image_url  \
#  0     jackets  other  https://www.c-and-a.com/img/product/q_auto:goo...
#  1     jackets  other  https://www.c-and-a.com/img/product/q_auto:goo...
#  2     jackets  other  https://www.c-and-a.com/img/product/q_auto:goo...
#  3    sweaters  other  https://www.c-and-a.com/img/product/q_auto:goo...
#  4     jackets  other  https://www.c-and-a.com/img/product/q_auto:goo...
#  ..        ...    ...                                                ...
#  513    shirts   hemd  https://www.c-and-a.com/img/product/q_auto:goo...
#  514    shirts   hemd  https://www.c-and-a.com/img/product/q_auto:goo...
#  516    shirts   hemd  https://www.c-and-a.com/img/product/q_auto:goo...
#  517    shirts   hemd  https://www.c-and-a.com/img/product/q_auto:goo...
#  518    shirts   hemd  https://www.c-and-a.com/img/product/q_auto:goo...
#
#                                             product_url         scrape_date  \
#  0    https://www.c-and-a.com/de/de/shop/baby-jacke-... 2025-03-12 14:30:17
#  1    https://www.c-and-a.com/de/de/shop/bluemchen-3... 2025-03-12 14:30:17
#  2    https://www.c-and-a.com/de/de/shop/baby-jacke-... 2025-03-12 14:30:17
#  3    https://www.c-and-a.com/de/de/shop/baby-sweatj... 2025-03-12 14:30:17
#  4    https://www.c-and-a.com/de/de/shop/bluemchen-b... 2025-03-12 14:30:17
#  ..                                                 ...                 ...
#  513  https://www.c-and-a.com/de/de/shop/businesshem... 2025-03-12 14:30:27
#  514  https://www.c-and-a.com/de/de/shop/businesshem... 2025-03-12 14:30:27
#  516  https://www.c-and-a.com/de/de/shop/businesshem... 2025-03-12 14:30:27
#  517  https://www.c-and-a.com/de/de/shop/businesshem... 2025-03-12 14:30:27
#  518  https://www.c-and-a.com/de/de/shop/businesshem... 2025-03-12 14:30:27
#
#       price_numeric  day_of_week  month
#  0            22.99            2      3
#  1            29.99            2      3
#  2            22.99            2      3
#  3            12.99            2      3
#  4            22.99            2      3
#  ..             ...          ...    ...
#  513          39.99            2      3
#  514          29.99            2      3
#  516          29.99            2      3
#  517          29.99            2      3
#  518          29.99            2      3
#
#  [423 rows x 11 columns]}

# %% [markdown]
# # Ridge Regression
# Kinda like linear, just with a bit of wanted error

# %%
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
import numpy as np

# Get training and testing data from dictionary
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")

# Display first few feature names
print(f"Example features: {data['feature_names'][:5]}")

# Create and train Ridge regression model
# Alpha parameter controls the strength of regularization 
# Higher alpha = stronger regularization
ridge = Ridge(alpha=0.5)
ridge.fit(X_train, y_train)

# Evaluation
score = ridge.score(X_test, y_test)
print(f"R² score: {score:.4f}")

y_predictions = ridge.predict(X_test)
# Out:
# Training data shape: (338, 136)
# Testing data shape: (85, 136)
# Example features: ['category_accessories', 'category_baby', 'category_dresses', 'category_jackets', 'category_jeans']
# R² score: 0.4559

# %%
# Create scatter plot of actual vs predicted values
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(y_test, y_predictions, alpha=0.7)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', label='Perfect prediction')
ax.set_xlabel('Actual Price')
ax.set_ylabel('Predicted Price')
ax.set_title('Actual vs Predicted Values')
ax.grid(True, linestyle='--', alpha=0.6)
plt.show()
