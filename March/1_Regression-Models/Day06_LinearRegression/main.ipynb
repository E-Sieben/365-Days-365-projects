# %%
# Getting Data
from sys import path
path.append('../..')
from getTrainingData import getTrainingData

# Get data using the improved function
data = getTrainingData(test_size=0.2, random_state=42, scale_features=True)
data
# Out:
# {'X_train':      category_accessories  category_dresses  category_jackets  category_jeans  \
#  357             -0.088475         -0.184761         -0.403148        2.585840
#  366             -0.088475         -0.184761         -0.403148        2.585840
#  188             -0.088475         -0.184761         -0.403148       -0.386722
#  307             -0.088475         -0.184761         -0.403148       -0.386722
#  545             -0.088475         -0.184761          2.480479       -0.386722
#  ..                    ...               ...               ...             ...
#  78              -0.088475         -0.184761         -0.403148       -0.386722
#  115             -0.088475         -0.184761         -0.403148       -0.386722
#  305             -0.088475         -0.184761         -0.403148       -0.386722
#  478             -0.088475         -0.184761         -0.403148        2.585840
#  111             -0.088475         -0.184761         -0.403148       -0.386722
#
#       category_other  category_pants  category_shirts  category_skirts  \
#  357       -0.453970       -0.305644        -0.581087        -0.088475
#  366       -0.453970       -0.305644        -0.581087        -0.088475
#  188        2.202787       -0.305644        -0.581087        -0.088475
#  307       -0.453970       -0.305644         1.720912        -0.088475
#  545       -0.453970       -0.305644        -0.581087        -0.088475
#  ..              ...             ...              ...              ...
#  78         2.202787       -0.305644        -0.581087        -0.088475
#  115        2.202787       -0.305644        -0.581087        -0.088475
#  305       -0.453970       -0.305644         1.720912        -0.088475
#  478       -0.453970       -0.305644        -0.581087        -0.088475
#  111       -0.453970       -0.305644         1.720912        -0.088475
#
#       category_sweaters  category_underwear  ...       und     waist  \
#  357          -0.428845           -0.076547  ... -0.236097 -0.169629
#  366          -0.428845           -0.076547  ... -0.236097 -0.169629
#  188          -0.428845           -0.076547  ... -0.236097 -0.169629
#  307          -0.428845           -0.076547  ... -0.236097 -0.169629
#  545          -0.428845           -0.076547  ... -0.236097 -0.169629
#  ..                 ...                 ...  ...       ...       ...
#  78           -0.428845           -0.076547  ... -0.236097 -0.169629
#  115          -0.428845           -0.076547  ... -0.236097 -0.169629
#  305          -0.428845           -0.076547  ... -0.236097 -0.169629
#  478          -0.428845           -0.076547  ... -0.236097 -0.169629
#  111          -0.428845           -0.076547  ... -0.236097 -0.169629
#
#       wasserabweisend      way     weste  wickelbody      wide  wildtiere  \
#  357        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  366        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  188        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  307        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  545        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  ..               ...      ...       ...         ...       ...        ...
#  78         -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  115        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  305        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  478        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#  111        -0.107388 -0.12548 -0.145438   -0.125134 -0.107322  -0.086863
#
#       day_of_week  month
#  357          0.0    0.0
#  366          0.0    0.0
#  188          0.0    0.0
#  307          0.0    0.0
#  545          0.0    0.0
#  ..           ...    ...
#  78           0.0    0.0
#  115          0.0    0.0
#  305          0.0    0.0
#  478          0.0    0.0
#  111          0.0    0.0
#
#  [412 rows x 132 columns],
#  'X_test':      category_accessories  category_dresses  category_jackets  category_jeans  \
#  341             -0.088475         -0.184761         -0.403148        2.585840
#  549             -0.088475         -0.184761         -0.403148       -0.386722
#  563    19.99
#  Name: price_numeric, Length: 103, dtype: float64,
#  'feature_names': ['category_accessories',
#   'category_dresses',
#   'category_jackets',
#   'category_jeans',
#   'category_other',
#   'category_pants',
#   'category_shirts',
#   'category_skirts',
#   'category_sweaters',
#   'category_underwear',
#   'category_vests',
#   'type_bag',
#   'type_blazer',
#   'type_bluse',
#   'type_cardigan',
#   'type_hemd',
#   'type_hoodie',
#   'type_jeans',
#   'type_leggings',
#   'type_other',
#   'type_poloshirt',
#   'type_pullover',
#   'type_shirt',
#   'type_shorts',
#   'type_steppjacke',
#   'type_suit',
#   'type_t-shirt',
#   'type_top',
#   'type_tshirt',
#   'type_vest',
#   '2er',
#   '3er',
#   '5er',
#   'ausschnitt',
#   'baby',
#   'baggy',
#   'basic',
#   'baukasten',
#   'blazer',
#   'bluse',
#   'blümchen',
#   'body',
#   'business',
#   'businesshemd',
#   'bärchen',
#   'bügelleicht',
#   'cargo',
#   'chase',
#   'chino',
#   'crop',
#   'cutaway',
#   'denim',
#   'die',
#   'dino',
#   'eiskönigin',
#   'fit',
#   'flare',
#   'flex',
#   'funktions',
#   'geblümt',
#   'gemustert',
#   'gerippt',
#   'gestreift',
#   'high',
#   'hoodie',
#   'hose',
#   'häschen',
#   'jacke',
#   'jeans',
#   'jog',
#   'jogginghose',
#   'kapuze',
#   'kariert',
#   'kent',
#   'kleid',
#   'krawatte',
#   'kurzarmshirt',
#   'lange',
#   'leg',
#   'leinen',
#   'leo',
#   'lilo',
#   'lycra',
#   'match',
#   'maus',
#   'minecraft',
#   'minnie',
#   'mit',
#   'mix',
#   'motiv',
#   'multipack',
#   'outfit',
#   'oversized',
#   'patrol',
#   'paw',
#   'pokémon',
#   'print',
#   'pyjama',
#   'regular',
#   'relaxed',
#   'rock',
#   'sakko',
#   'schlafanzug',
#   'schurwoll',
#   'schäfchen',
#   'set',
#   'shorty',
#   'slim',
#   'socken',
#   'spider',
#   'stitch',
#   'straight',
#   'strampler',
#   'stretch',
#   'strick',
#   'strickjacke',
#   'strukturiert',
#   'sweatjacke',
#   'sweatshirt',
#   'tapered',
#   'teilig',
#   'traktor',
#   'und',
#   'waist',
#   'wasserabweisend',
#   'way',
#   'weste',
#   'wickelbody',
#   'wide',
#   'wildtiere',
#   'day_of_week',
#   'month'],
#  'encoder': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'vectorizer': TfidfVectorizer(max_features=100),
#  'scaler': StandardScaler(),
#  'original_data':      product_id                       title  price  category      type  \
#  0       2243592      Sweatjacke - gestreift  22,99  sweaters     other
#  1       2237930      Strick-Weste - gerippt  22,99  sweaters      vest
#  2       2235344  Strickjacke - strukturiert  25,99  sweaters  cardigan
#  3       2234086                Strick-Weste  25,99  sweaters      vest
#  4       2191838           Basic-Strickjacke   7,99  sweaters  cardigan
#  ..          ...                         ...    ...       ...       ...
#  562     2238800                  Sweatshirt  19,99    shirts    tshirt
#  563     2238722                  Sweatshirt  19,99    shirts    tshirt
#  564     2238724                      Hoodie  22,99  sweaters    hoodie
#  565     2235232            Oversized-Hoodie  19,99  sweaters    hoodie
#  566     2238727                  Sweatshirt  19,99    shirts    tshirt
#
#                                               image_url  \
#  0    https://www.c-and-a.com/img/product/q_auto:goo...
#  1    https://www.c-and-a.com/img/product/q_auto:goo...
#  2    https://www.c-and-a.com/img/product/q_auto:goo...
#  3    https://www.c-and-a.com/img/product/q_auto:goo...
#  4    https://www.c-and-a.com/img/product/q_auto:goo...
#  ..                                                 ...
#  562  https://www.c-and-a.com/img/product/q_auto:goo...
#  563  https://www.c-and-a.com/img/product/q_auto:goo...
#  564  https://www.c-and-a.com/img/product/q_auto:goo...
#  565  https://www.c-and-a.com/img/product/q_auto:goo...
#  566  https://www.c-and-a.com/img/product/q_auto:goo...
#
#                                             product_url         scrape_date  \
#  0    https://www.c-and-a.com/de/de/shop/sweatjacke-... 2025-03-21 22:08:18
#  1    https://www.c-and-a.com/de/de/shop/strick-west... 2025-03-21 22:08:18
#  2    https://www.c-and-a.com/de/de/shop/strickjacke... 2025-03-21 22:08:18
#  3    https://www.c-and-a.com/de/de/shop/strick-west... 2025-03-21 22:08:18
#  4    https://www.c-and-a.com/de/de/shop/basic-stric... 2025-03-21 22:08:18
#  ..                                                 ...                 ...
#  562  https://www.c-and-a.com/de/de/shop/sweatshirt-... 2025-03-21 22:08:25
#  563  https://www.c-and-a.com/de/de/shop/sweatshirt-... 2025-03-21 22:08:25
#  564  https://www.c-and-a.com/de/de/shop/hoodie-2238... 2025-03-21 22:08:25
#  565  https://www.c-and-a.com/de/de/shop/oversized-h... 2025-03-21 22:08:25
#  566  https://www.c-and-a.com/de/de/shop/sweatshirt-... 2025-03-21 22:08:25
#
#       price_numeric  day_of_week  month
#  0            22.99            4      3
#  1            22.99            4      3
#  2            25.99            4      3
#  3            25.99            4      3
#  4             7.99            4      3
#  ..             ...          ...    ...
#  562          19.99            4      3
#  563          19.99            4      3
#  564          22.99            4      3
#  565          19.99            4      3
#  566          19.99            4      3
#
#  [515 rows x 11 columns]}

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# Get training and testing data from dictionary
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")

# Display first few feature names
print(f"Example features: {data['feature_names'][:5]}")
# Out:
# Training data shape: (412, 132)
# Testing data shape: (103, 132)
# Example features: ['category_accessories', 'category_dresses', 'category_jackets', 'category_jeans', 'category_other']

# %% [markdown]
# ## Creating and training the Model

# %%
lreg = LinearRegression()
lreg.fit(X_train, y_train)
score = lreg.score(X_test, y_test)
print(f"R² score: {score:.4f}")
# Out:
# R² score: 0.7722

# %%
# Generating price predictions
y_predictions = lreg.predict(X_test)

# %% [markdown]
# ## Plotting Predictions

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_predictions, color='b')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='k')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()
